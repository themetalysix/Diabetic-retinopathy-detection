# %%
pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\fehin\schlscrape_project\scrape_venv\lib\site-packages (from ucimlrepo) (2.2.3)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\fehin\schlscrape_project\scrape_venv\lib\site-packages (from ucimlrepo) (2025.1.31)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\fehin\schlscrape_project\scrape_venv\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fehin\schlscrape_project\scrape_venv\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fehin\schlscrape_project\scrape_venv\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\fehin\schlscrape_project\scrape_venv\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\fehin\schlscrape_project\scrape_venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\fehin\schlscrape_project\scrape_venv\Scripts\python.exe -m pip install --upgrade pip

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
diabetic_retinopathy_debrecen = fetch_ucirepo(id=329) 
  
# data (as pandas dataframes) 
X = diabetic_retinopathy_debrecen.data.features 
y = diabetic_retinopathy_debrecen.data.targets

# %%
# metadata 
print(diabetic_retinopathy_debrecen.metadata)
# Out:
# {'uci_id': 329, 'name': 'Diabetic Retinopathy Debrecen', 'repository_url': 'https://archive.ics.uci.edu/dataset/329/diabetic+retinopathy+debrecen', 'data_url': 'https://archive.ics.uci.edu/static/public/329/data.csv', 'abstract': 'This dataset contains features extracted from the Messidor image set to predict whether an image contains signs of diabetic retinopathy or not. ', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 1151, 'num_features': 19, 'feature_types': ['Integer', 'Real'], 'demographics': [], 'target_col': ['Class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2014, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C5XP4P', 'creators': ['Balint Antal', 'Andras Hajdu'], 'intro_paper': {'ID': 226, 'type': 'NATIVE', 'title': 'An ensemble-based system for automatic screening of diabetic retinopathy', 'authors': 'B. Antal, A. Hajdu', 'venue': 'Knowledge-Based Systems', 'year': 2014, 'journal': None, 'DOI': 'https://doi.org/10.1016/j.knosys.2013.12.023', 'URL': 'https://dl.acm.org/doi/abs/10.1016/j.knosys.2013.12.023', 'sha': None, 'corpus': None, 'arxiv': None, 'mag': None, 'acl': None, 'pmid': None, 'pmcid': None}, 'additional_info': {'summary': 'This dataset contains features extracted from the Messidor image set to predict whether an image contains signs of diabetic retinopathy or not. All features represent either a detected lesion, a descriptive feature of a anatomical part or an image-level descriptor. The underlying method image analysis and feature extraction as well as our classification technique is described in Antal and Hajdu, Knowledge-Based Systems, 2014. \n\nThe image set (Messidor) is available at http://messidor.crihan.fr/index-en.php.', 'purpose': None, 'funded_by': None, 'instances_represent': 'Medical patients', 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': '0) The binary result of quality assessment. 0 = bad quality 1 = sufficient quality.\r\n1) The binary result of pre-screening, where 1 indicates severe retinal abnormality and 0 its lack.\r\n2-7) The results of MA detection. Each feature value stand for the\r\nnumber of MAs found at the confidence levels alpha = 0.5, . . . , 1, respectively.\r\n8-15) contain the same information as 2-7) for exudates. However,\r\nas exudates are represented by a set of points rather than the number of\r\npixels constructing the lesions, these features are normalized by dividing the\r\nnumber of lesions with the diameter of the ROI to compensate different image\r\nsizes.\r\n16) The euclidean distance of the center of\r\nthe macula and the center of the optic disc to provide important information\r\nregarding the patientâ€™s condition. This feature\r\nis also normalized with the diameter of the ROI.\r\n17) The diameter of the optic disc.\r\n18) The binary result of the AM/FM-based classification.\r\n19) Class label. 1 = contains signs of DR (Accumulative label for the Messidor classes 1, 2, 3), 0 = no signs of DR.', 'citation': None}}

# %%
# variable information 
print(diabetic_retinopathy_debrecen.variables)
# Out:
#                          name     role        type demographic  \
# 0                     quality  Feature      Binary        None
# 1               pre_screening  Feature      Binary        None
# 2                         ma1  Feature     Integer        None
# 3                         ma2  Feature     Integer        None
# 4                         ma3  Feature     Integer        None
# 5                         ma4  Feature     Integer        None
# 6                         ma5  Feature     Integer        None
# 7                         ma6  Feature     Integer        None
# 8                    exudate1  Feature  Continuous        None
# 9                    exudate2  Feature  Continuous        None
# 10                   exudate3  Feature  Continuous        None
# 11                   exudate3  Feature  Continuous        None
# 12                   exudate5  Feature  Continuous        None
# 13                   exudate6  Feature  Continuous        None
# 14                   exudate7  Feature  Continuous        None
# 15                   exudate8  Feature  Continuous        None
# 16  macula_opticdisc_distance  Feature  Continuous        None
# 17         opticdisc_diameter  Feature  Continuous        None
# 18       am_fm_classification  Feature      Binary        None
# 19                      Class   Target      Binary        None
#
#                                           description units missing_values
# 0   The binary result of quality assessment. 0 = b...  None             no
# 1   The binary result of pre-screening, where 1 in...  None             no
# 2   ma1 - ma-6 contain the results of MA detection...  None             no
# 3                                                None  None             no
# 4                                                None  None             no
# 5                                                None  None             no
# 6                                                None  None             no
# 7                                                None  None             no
# 8   exudate1 - exudate8 contain the same informati...  None             no
# 9                                                None  None             no
# 10                                               None  None             no
# 11                                               None  None             no
# 12                                               None  None             no
# 13                                               None  None             no
# 14                                               None  None             no
# 15                                               None  None             no
# 16  The euclidean distance of the center of the ma...  None             no
# 17                    The diameter of the optic disc.  None             no
# 18  The binary result of the AM/FM-based classific...  None             no
# 19  Class label. 1 = contains signs of DR (Accumul...  None             no

# %%
X.head()
# Out:
#    quality  pre_screening  ma1  ma2  ma3  ma4  ma5  ma6   exudate1   exudate2  \
# 0        1              1   22   22   22   19   18   14  49.895756  17.775994
# 1        1              1   24   24   22   18   16   13  57.709936  23.799994
# 2        1              1   62   60   59   54   47   33  55.831441  27.993933
# 3        1              1   55   53   53   50   43   31  40.467228  18.445954
# 4        1              1   44   44   44   41   39   27  18.026254   8.570709
#
#     exudate3   exudate3  exudate5  exudate6  exudate7  exudate8  \
# 0   5.270920   5.270920  0.018632  0.006864  0.003923  0.003923
# 1   3.325423   3.325423  0.003903  0.003903  0.003903  0.003903
# 2  12.687485  12.687485  1.393889  0.373252  0.041817  0.007744
# 3   9.118901   9.118901  0.840261  0.272434  0.007653  0.001531
# 4   0.410381   0.410381  0.000000  0.000000  0.000000  0.000000
#
#    macula_opticdisc_distance  opticdisc_diameter  am_fm_classification
# 0                   0.486903            0.100025                     1
# 1                   0.520908            0.144414                     0
# 2                   0.530904            0.128548                     0
# 3                   0.483284            0.114790                     0
# 4                   0.475935            0.123572                     0

# %%
y.head()
# Out:
#    Class
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %%
X.shape[1]
# Out:
# 19

# %%
X.columns
# Out:
# Index(['quality', 'pre_screening', 'ma1', 'ma2', 'ma3', 'ma4', 'ma5', 'ma6',
#        'exudate1', 'exudate2', 'exudate3', 'exudate3', 'exudate5', 'exudate6',
#        'exudate7', 'exudate8', 'macula_opticdisc_distance',
#        'opticdisc_diameter', 'am_fm_classification'],
#       dtype='object')

# %%
y.value_counts()
# Out:
# Class
# 1        611
# 0        540
# Name: count, dtype: int64

# %%
X.isnull().sum()
# Out:
# quality                      0
# pre_screening                0
# ma1                          0
# ma2                          0
# ma3                          0
# ma4                          0
# ma5                          0
# ma6                          0
# exudate1                     0
# exudate2                     0
# exudate3                     0
# exudate3                     0
# exudate5                     0
# exudate6                     0
# exudate7                     0
# exudate8                     0
# macula_opticdisc_distance    0
# opticdisc_diameter           0
# am_fm_classification         0
# dtype: int64

# %%
X.describe()
# Out:
#            quality  pre_screening          ma1          ma2          ma3  \
# count  1151.000000    1151.000000  1151.000000  1151.000000  1151.000000
# mean      0.996525       0.918332    38.428323    36.909644    35.140747
# std       0.058874       0.273977    25.620913    24.105612    22.805400
# min       0.000000       0.000000     1.000000     1.000000     1.000000
# 25%       1.000000       1.000000    16.000000    16.000000    15.000000
# 50%       1.000000       1.000000    35.000000    35.000000    32.000000
# 75%       1.000000       1.000000    55.000000    53.000000    51.000000
# max       1.000000       1.000000   151.000000   132.000000   120.000000
#
#                ma4          ma5          ma6     exudate1     exudate2  \
# count  1151.000000  1151.000000  1151.000000  1151.000000  1151.000000
# mean     32.297133    28.747176    21.151173    64.096674    23.088012
# std      21.114767    19.509227    15.101560    58.485289    21.602696
# min       1.000000     1.000000     1.000000     0.349274     0.000000
# 25%      14.000000    11.000000     8.000000    22.271597     7.939315
# 50%      29.000000    25.000000    18.000000    44.249119    17.038020
# 75%      48.000000    43.000000    32.000000    87.804112    31.305692
# max     105.000000    97.000000    89.000000   403.939108   167.131427
#
#           exudate3     exudate3     exudate5     exudate6     exudate7  \
# count  1151.000000  1151.000000  1151.000000  1151.000000  1151.000000
# mean      8.704610     8.704610     0.560738     0.212290     0.085674
# std      11.567589    11.567589     2.484111     1.057126     0.398717
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.249050     1.249050     0.000000     0.000000     0.000000
# 50%       4.423472     4.423472     0.022248     0.001554     0.000000
# 75%      11.766880    11.766880     0.191953     0.038450     0.004832
# max     106.070092   106.070092    51.423208    20.098605     5.937799
#
#           exudate8  macula_opticdisc_distance  opticdisc_diameter  \
# count  1151.000000                1151.000000         1151.000000
# mean      0.037225                   0.523212            0.108431
# std       0.178959                   0.028055            0.017945
# min       0.000000                   0.367762            0.057906
# 25%       0.000000                   0.502855            0.095799
# 50%       0.000000                   0.523308            0.106623
# 75%       0.003851                   0.543670            0.119591
# max       3.086753                   0.592217            0.219199
#
#        am_fm_classification
# count           1151.000000
# mean               0.336229
# std                0.472624
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                1.000000
# max                1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns  

# To set the style for graphs
sns.set_style("whitegrid")

# Plotting histograms for all features
X.hist(figsize=(12, 8), bins=20)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=X)
plt.xticks(rotation=90)  # Rotate labels for readability
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(X.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()
